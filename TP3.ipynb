# %%
# Pandas y numpy para manipulación
import pandas as pd
import numpy as np
import glob as glob
import os as os
# Librerias para gráficos 
import seaborn as sns
import matplotlib.pyplot as plt
# Herramientas de modelado
import graphviz
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import accuracy_score

# %% [markdown]
# Unir los dataset csv

# %%
# merging the files
files_joined = os.path.join('./dataset/Electricity/', "*.csv")

# Return a list of all joined files
list_files = glob.glob(files_joined)

print("** Merging multiple csv files into a single pandas dataframe **")
# Merge files by joining all files
dataframe = pd.concat(map(pd.read_csv, list_files), ignore_index=True)
print(dataframe)
# Out:
# ** Merging multiple csv files into a single pandas dataframe **
#                 net_manager                          purchase_area  \
# 0        Coteq Netbeheer BV  Netbeheerder Centraal Overijssel B.V.
# 1        Coteq Netbeheer BV  Netbeheerder Centraal Overijssel B.V.
# 2        Coteq Netbeheer BV  Netbeheerder Centraal Overijssel B.V.
# 3        Coteq Netbeheer BV  Netbeheerder Centraal Overijssel B.V.
# 4        Coteq Netbeheer BV  Netbeheerder Centraal Overijssel B.V.
# ...                     ...                                    ...
# 2779986      westland-infra                     871687800090000015
# 2779987      westland-infra                     871687800090000015
# 2779988      westland-infra                     871687800090000015
# 2779989      westland-infra                     871687800090000015
# 2779990      westland-infra                     871687800090000015
#
#                       street zipcode_from zipcode_to      city  \
# ...

# %%
dataframe.sample(5)
# Out:
#                net_manager      purchase_area                   street  \
# 1192277  Liander N.V. (NW)                NaN       Piet de Winterlaan
# 2072003      8716874000009     Stedin Utrecht    Charles Weddepohllaan
# 914719   Liander N.V. (NW)         Liander NW  Van Heuven Goedhartlaan
# 1119151       Liander N.V.                NaN                  Tolhuis
# 31746        8716902000001  Enduris Netgebied          Helmkruidstraat
#
#         zipcode_from zipcode_to                city  num_connections  \
# 1192277       1183WB     1183WB          AMSTELVEEN             22.0
# 2072003       3739LE     3739LE  HOLLANDSCHE RADING             23.0
# 914719        1181LJ     1181LJ          AMSTELVEEN             28.0
# 1119151       6537ST     6537ST            NIJMEGEN             25.0
# 31746         4341JX     4341JX          ARNEMUIDEN             16.0
#
#          delivery_perc  perc_of_active_connections type_conn_perc  \
# ...

# %%
data_describe = pd.DataFrame(round(dataframe.isnull().sum() /dataframe.shape[0],2), columns= ['Porcentaje de nulos'])
data_describe['type'] = dataframe.dtypes
data_describe = data_describe[['type','Porcentaje de nulos']]
data_describe['Nulos'] = dataframe.isnull().sum()
values= []
example=[]
for x in dataframe:
    values.append(len(dataframe[x].unique()))
    example.append(dataframe[x].unique())
data_describe['Valores distintos'] = values
data_describe['Ejemplos'] = example

data_describe
# Out:
#                                  type  Porcentaje de nulos    Nulos  \
# net_manager                    object                 0.01    29224
# purchase_area                  object                 0.32   886657
# street                         object                 0.00        0
# zipcode_from                   object                 0.00        0
# zipcode_to                     object                 0.00        0
# city                           object                 0.00        0
# num_connections               float64                 0.00        7
# delivery_perc                 float64                 0.00     1487
# perc_of_active_connections    float64                 0.00     1487
# type_conn_perc                 object                 0.00        7
# type_of_connection             object                 0.00        7
# annual_consume                float64                 0.00        0
# annual_consume_lowtarif_perc  float64                 0.00    13268
# ...
